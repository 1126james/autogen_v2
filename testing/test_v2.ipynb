# %%
# Somehow in mac, it cant find local packages
# Run this to solve no local modules found in mac
import os
import sys

# Get the project root directory (assuming your notebook is in a subdirectory)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# Python lib
import asyncio
from pathlib import Path
import pandas as pd
from tqdm import tqdm
from typing import Dict, Any, Tuple, List
import venv
import os

# Autogen-0.4
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.agents._code_executor_agent import CodeExecutorAgent
from autogen_agentchat.conditions import TextMentionTermination, MaxMessageTermination
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_ext.models.openai.config import OpenAIClientConfigurationConfigModel
from autogen_core.model_context import BufferedChatCompletionContext

# Local
from utils import get_dataset_profile, get_columns_sample, initialize_individual_chat, _fix_file_name
from prompts import data_dict_generator_prompt

# %%
# Uses utils/get_dataset_profile
root = '../sheets/mysql/'
files: list[str] = os.listdir(path=root)
tasks = [get_dataset_profile(root, file_name = file, output_format='json') for file in files]
results = await asyncio.gather(*tasks)
result_dict = zip(files, results)
results = list(result_dict)
# Out:
# Processing 13 columns (customer.csv)                                   ██████████████████████████████|  13/13
# Processing 8 columns (employee.csv)                                                                  |   0/8
# Processing 8 columns (employee.csv)                                    ██████████████████████████████|   8/8
# Processing 9 columns (office.csv)                                      ██████████████████████████████|   9/9
# Processing 5 columns (orderdetails.csv)                                ██████████████████████████████|   5/5
# Processing 7 columns (orders.csv)                                      ██████████████████████████████|   7/7
# Processing 4 columns (payments.csv)                                    ██████████████████████████████|   4/4
# Processing 4 columns (productlines.csv)                                ██████████████████████████████|   4/4
# Processing 9 columns (products.csv)                                    ██████████████████████████████|   9/9

# %%
# Uses utils/get_columns_sample
root = '../sheets/mysql/'
files: list[str] = os.listdir(path=root)
tasks = [get_columns_sample(root, file_name = file) for file in files]
results = await asyncio.gather(*tasks)
result_dict = zip(files, results)
results = list(result_dict)

# %%
type(results[0][0])
# Out:
# str

# %%
# Only edit here AND filepath under if __name__ == "__main__":
data_dict_summarizer = "qwen2.5:32b-instruct-q8_0-32768"
data_dict_generator = "qwen2.5:32b-instruct-q8_0"

data_dict_summarizer_ds = "deepseek-r1:32b-qwen-distill-q8_0-131072"
data_dict_generator_ds = "deepseek-r1:32b-qwen-distill-q8_0"

# Common config
llm_base_url = "http://34.204.63.234:11434/v1"
api_key = "none"
model_info =  {
        "vision": False,
        "function_calling": False,
        "json_output": True,
        "family": "Qwen2.5"
    }

#######################################################################
#   !!! DONT EDIT BELOW EXCEPT FOR if __name__ == "__main__":   !!!   #
#######################################################################


# Create reasoning config
# Need to be more creative
data_dict_summarizer_config = OpenAIClientConfigurationConfigModel(
    frequency_penalty=0.2, 
    logit_bias=None, 
    max_tokens=128000, 
    n=None, 
    presence_penalty=0.5, 
    response_format=None, 
    seed=42, 
    stop=None, 
    temperature=0.8, 
    top_p=0.95, 
    user=None,
    model=data_dict_summarizer,
    api_key='none', 
    timeout=None, 
    max_retries=None, 
    model_info=model_info, 
    organization=None, 
    base_url='http://34.204.63.234:11434/v1'
    )

# Just generate the data dict based on obervered facts
data_dict_generator_config = OpenAIClientConfigurationConfigModel(
    frequency_penalty=0.4, 
    logit_bias=None, 
    max_tokens=2048, 
    n=None, 
    presence_penalty=0.3, 
    response_format={"type": "json_object"},
    seed=42, 
    stop=None, 
    temperature=0.2, 
    top_p=0.7, 
    user=None,
    model=data_dict_generator,
    api_key='none', 
    timeout=None, 
    max_retries=None, 
    model_info=model_info, 
    organization=None, 
    base_url='http://34.204.63.234:11434/v1'
    )

# %%
data_dict_summarizer_client = OpenAIChatCompletionClient(model=data_dict_summarizer, model_info=model_info)._from_config(data_dict_summarizer_config)
data_dict_generator_client = OpenAIChatCompletionClient(model=data_dict_generator, model_info=model_info)._from_config(data_dict_generator_config)

# %%
results[0][0]
# Out:
# 'customer.csv'

# %%
# Create a list of tasks for all agents
tasks = [initialize_individual_chat(filename=results[index][0], metadata=results[index][1], data_dict_generator_client=data_dict_generator_client) for index in range(len(results))]

# Execute all agent chat tasks concurrently
responses = await asyncio.gather(*tasks)
print(responses)
# Out:
# [Response(chat_message=TextMessage(source='File_handler_customer_csv', models_usage=RequestUsage(prompt_tokens=751, completion_tokens=1081), content='{\n  "Data Dictionary": {\n    "filename": "customer.csv",\n    "columns": [\n      {\n        "Column": "customerNumber",\n        "Description": "Unique identifier for each customer.",\n        "Format": "Identifier: Starts with a number like 103, 112, etc.",\n        "Nullable": false,\n        "Sample Values": ["103", "112", "114"]\n      },\n      {\n        "Column": "customerName",\n        "Description": "The name of the customer company or individual.",\n        "Format": "Text: Contains free-form text strings like \'Atelier graphique\', \'Signal Gift Stores\'.",\n        "Nullable": false,\n        "Sample Values": ["Atelier graphique", "Signal Gift Stores", "Australian Collectors, Co."]\n      },\n      {\n        "Column": "contactLastName",\n        "Description": "The last name of the contact person for the customer.",\n        "Format": "Text: Contains free-form text strings like \'Schmitt\', \'King\'.",\n        "Nullable": false,\n        "Sample Values": ["Schmitt", "King", "Ferguson"]\n      },\n      {\n        "Column": "contactFirstName",\n        "Description": "The first name of the contact person for the customer.",\n        "Format": "Text: Contains free-form text strings like \'Carine\', \'Jean\'.",\n        "Nullable": false,\n        "Sample Values": ["Carine ", "Jean", "Peter"]\n      },\n      {\n        "Column": "phone",\n        "Description": "The phone number of the customer.",\n        "Format": "Text: Contains free-form text strings like \'40.32.2555\', \'7025551838\'.",\n        "Nullable": false,\n        "Sample Values": ["40.32.2555", "7025551838", "03 9520 4555"]\n      },\n      {\n        "Column": "addressLine1",\n        "Description": "The first line of the customer\'s address.",\n        "Format": "Text: Contains free-form text strings like \'54, rue Royale\', \'8489 Strong St.\'. ",\n        "Nullable": false,\n        "Sample Values": ["54, rue Royale", "8489 Strong St.", "636 St Kilda Road"]\n      },\n      {\n        "Column": "addressLine2",\n        "Description": "The second line of the customer\'s address.",\n        "Format": "Text: Contains free-form text strings like \'Level 3\', \'Bronz Apt. 3/6 Tesvikiye\'.",\n        "Nullable": true,\n        "Sample Values": ["Level 3", "Bronz Apt. 3/6 Tesvikiye", "Suite 400"]\n      },\n      {\n        "Column": "city",\n        "Description": "The city where the customer is located.",\n        "Format": "Text: Contains free-form text strings like \'Nantes\', \'Las Vegas\'.",\n        "Nullable": false,\n        "Sample Values": ["Nantes", "Las Vegas", "Melbourne"]\n      },\n      {\n        "Column": "state",\n        "Description": "The state or province where the customer is located.",\n        "Format": "Text: Contains free-form text strings like \'NV\', \'Victoria\'.",\n        "Nullable": true,\n        "Sample Values": ["NV", "", "CA"]\n      },\n      {\n        "Column": "postalCode",\n        "Description": "The postal or zip code of the customer\'s address.",\n        "Format": "Text: Contains free-form text strings like \'44000\', \'83030\'.",\n        "Nullable": true,\n        "Sample Values": ["44000", "83030", "3004"]\n      },\n      {\n        "Column": "country",\n        "Description": "The country where the customer is located.",\n        "Format": "Text: Contains free-form text strings like \'France\', \'USA\'.",\n        "Nullable": false,\n        "Sample Values": ["France", "USA", "Australia"]\n      },\n      {\n        "Column": "salesRepEmployeeNumber",\n        "Description": "The employee number of the sales representative assigned to the customer.",\n        "Format": "Identifier: Starts with a number like 1370, 1166, etc.",\n        "Nullable": true,\n        "Sample Values": ["1370", "1166", "1611"]\n      },\n      {\n        "Column": "creditLi ...

# %%
results[0][1]
# Out:
# 'customer.csv'

# %%
# Example usage
print(responses)
print(f"\nResponses received: {len(responses)}")

# %%
print(responses[0].chat_message.content)
# Out:
# {
#   "Data Dictionary": {
#     "filename": "customer.csv",
#     "columns": [
#       {
#         "Column": "customerNumber",
#         "Description": "Unique identifier for each customer.",
#         "Format": "Identifier: Starts with a number like 103, 112, etc.",
#         "Nullable": false,
#         "Sample Values": ["103", "112", "114"]
#       },
#       {
#         "Column": "customerName",
#         "Description": "The name of the customer company or individual.",
#         "Format": "Text: Contains free-form text strings like 'Atelier graphique', 'Signal Gift Stores'.",
#         "Nullable": false,
#         "Sample Values": ["Atelier graphique", "Signal Gift Stores", "Australian Collectors, Co."]
#       },
#       {
#         "Column": "contactLastName",
#         "Description": "The last name of the contact person for the customer.",
#         "Format": "Text: Contains free-form text strings like 'Schmitt', 'King'.",
#         "Nullable": false,
#         "Sample Values": ["Schmitt", "King", "Ferguson"]
#       },
#       {
#         "Column": "contactFirstName",
#         "Description": "The first name of the contact person for the customer.",
#         "Format": "Text: Contains free-form text strings like 'Carine', 'Jean'.",
#         "Nullable": false,
#         "Sample Values": ["Carine ", "Jean", "Peter"]
#       },
#       {
#         "Column": "phone",
#         "Description": "The phone number of the customer.",
#         "Format": "Text: Contains free-form text strings like '40.32.2555', '7025551838'.",
#         "Nullable": false,
#         "Sample Values": ["40.32.2555", "7025551838", "03 9520 4555"]
#       },
#       {
#         "Column": "addressLine1",
#         "Description": "The first line of the customer's address.",
#         "Format": "Text: Contains free-form text strings like '54, rue Royale', '8489 Strong St.'. ",
#         "Nullable": false,
#         "Sample Values": ["54, rue Royale", "8489 Strong St.", "636 St Kilda Road"]
#       },
#       {
#         "Column": "addressLine2",
#         "Description": "The second line of the customer's address.",
#         "Format": "Text: Contains free-form text strings like 'Level 3', 'Bronz Apt. 3/6 Tesvikiye'.",
#         "Nullable": true,
#         "Sample Values": ["Level 3", "Bronz Apt. 3/6 Tesvikiye", "Suite 400"]
#       },
#       {
#         "Column": "city",
#         "Description": "The city where the customer is located.",
#         "Format": "Text: Contains free-form text strings like 'Nantes', 'Las Vegas'.",
#         "Nullable": false,
#         "Sample Values": ["Nantes", "Las Vegas", "Melbourne"]
#       },
#       {
#         "Column": "state",
#         "Description": "The state or province where the customer is located.",
#         "Format": "Text: Contains free-form text strings like 'NV', 'Victoria'.",
#         "Nullable": true,
#         "Sample Values": ["NV", "", "CA"]
#       },
#       {
#         "Column": "postalCode",
#         "Description": "The postal or zip code of the customer's address.",
#         "Format": "Text: Contains free-form text strings like '44000', '83030'.",
#         "Nullable": true,
#         "Sample Values": ["44000", "83030", "3004"]
#       },
#       {
#         "Column": "country",
#         "Description": "The country where the customer is located.",
#         "Format": "Text: Contains free-form text strings like 'France', 'USA'.",
#         "Nullable": false,
#         "Sample Values": ["France", "USA", "Australia"]
#       },
#       {
#         "Column": "salesRepEmployeeNumber",
#         "Description": "The employee number of the sales representative assigned to the customer.",
#         "Format": "Identifier: Starts with a number like 1370, 1166, etc.",
#         "Nullable": true,
#         "Sample Values": ["1370", "1166", "1611"]
#       },
#       {
#         "Column": "creditLimit",
#         "Description": "The credit limit assigned to the customer.",
#         "Format": "Numeric: Contains decimal numbers like 21000.0, 71800.0.",
#         "Nullable": true,
#         "Sample Values": ["21000.0", "71800.0", "117300.0"]
#       }
#     ]
#   }
# }

# %%
import json
pydict = json.loads(responses[5].chat_message.content)
pydict
# Out:
# {'Data Dictionary for payments.csv': [{'Column': 'customerNumber',
#    'Possible meaning': 'Unique identifier for each customer.',
#    'Description': 'An integer value that uniquely identifies a specific customer within the dataset.',
#    'Relationships with other columns': 'This column could be used to link payment records back to individual customers, possibly correlating with data in another table or file containing detailed customer information.',
#    'Sample value': 103},
#   {'Column': 'checkNumber',
#    'Possible meaning': 'Unique identifier for each check/payment transaction.',
#    'Description': 'A string that uniquely identifies a payment made by the customer, likely used to track individual transactions or checks.',
#    'Relationships with other columns': "This column could be related to 'paymentDate' and 'amount', as it represents an instance of a specific amount being paid on a certain date.",
#    'Sample value': 'HQ336336'},
#   {'Column': 'paymentDate',
#    'Possible meaning': 'The date when the payment was made or processed.',
#    'Description': "A string representing the date in 'YYYY-MM-DD' format, indicating on which day a particular transaction occurred.",
#    'Relationships with other columns': "This column is likely to be analyzed alongside 'amount', as it provides context for when payments of specific amounts were made. It could also correlate with customer payment patterns over time.",
#    'Sample value': '2004-10-19'},
#   {'Column': 'amount',
#    'Possible meaning': 'The monetary amount paid in a transaction.',
#    'Description': 'A floating point number representing the total sum of money that was transferred or paid for each record.',
#    'Relationships with other columns': "This column is directly related to 'checkNumber' and 'paymentDate', as it specifies how much was paid on what date through which check. It could also be analyzed in conjunction with 'customerNumber' to understand payment behavior per customer.",
#    'Sample value': 6066.78}]}

# %%
# Extract class:: TextMessage from class:: Response
# Since agents only accept [TextMessage] as input prompt
responses_TextMessage = [json.loads(responses[index].chat_message.content) for index in range(len(responses))]
responses_TextMessage
# Out:
# [{'Data Dictionary for customer.csv': [{'Column': 'customerNumber',
#     'Possible meaning': 'Unique identifier for each customer.',
#     'Description': 'An integer that uniquely identifies a specific customer record within the dataset.',
#     'Relationships with other columns': 'This column is likely to be used as a foreign key in related tables such as orders or payments.',
#     'Sample value': 103},
#    {'Column': 'customerName',
#     'Possible meaning': "The name of the customer's company or individual.",
#     'Description': 'A string that represents the full name of the customer, which could be a business entity or an individual person.',
#     'Relationships with other columns': 'This column is often used in conjunction with contactLastName and contactFirstName to identify specific contacts within a customer record.',
#     'Sample value': 'Atelier graphique'},
#    {'Column': 'contactLastName',
#     'Possible meaning': 'The last name of the primary contact person for this customer.',
#     'Description': "A string that contains the surname or family name of the main point of contact at a customer's business or individual account.",
#     'Relationships with other columns': 'This column is often used together with contactFirstName to form full names and can be linked with salesRepEmployeeNumber if there are specific representatives assigned per last name basis.',
#     'Sample value': 'Schmitt'},
#    {'Column': 'contactFirstName',
#     'Possible meaning': 'The first name of the primary contact person for this customer.',
#     'Description': "A string that contains the given or personal name of the main point of contact at a customer's business or individual account.",
#     'Relationships with other columns': 'This column is often used together with contactLastName to form full names and can be linked with salesRepEmployeeNumber if there are specific representatives assigned per first name basis.',
#     'Sample value': 'Carine'},
#    {'Column': 'phone',
#     'Possible meaning': "The primary phone number for the customer's business or individual account.",
#     'Description': 'A string that contains a telephone number used to contact the customer. The format may vary by country and region.',
#     'Relationships with other columns': 'This column is often analyzed alongside addressLine1, city, state, postalCode, and country to provide comprehensive contact information for customers.',
#     'Sample value': '40.32.2555'},
#    {'Column': 'addressLine1',
#     'Possible meaning': "The first line of the customer's physical address.",
#     'Description': 'A string that contains part of a street address, often including house number and name or type of road.',
#     'Relationships with other columns': 'This column is typically used in conjunction with addressLine2 (if available), city, state, postalCode, and country to form the full mailing address for customers.',
#     'Sample value': '54, rue Royale'},
#    {'Column': 'addressLine2',
#     'Possible meaning': "The second line of the customer's physical address. This could include suite number or building name.",
#     'Description': 'A string that contains additional information about a street address such as an apartment number or floor level, but it is not always provided for every record.',
#     'Relationships with other columns': "This column complements addressLine1 and can be used together to provide more detailed location data. It's often analyzed alongside city, state, postalCode, and country.",
#     'Sample value': 'Level 3'},
#    {'Column': 'city',
#     'Possible meaning': 'The name of the city where the customer is located.',
#     'Description': "A string that represents a locality within which customers reside or conduct business. It's an essential part of their address information.",
#     'Relationships with other columns': 'This column is often used together with state, postalCode, and country to provide full geographical context for each record in the dataset.',
#     'Sample value': 'Nantes'},
#    {'Column': 'state',
#     'Possible meaning': 'The name or abbreviation of the administrative division (e.g., province, county) where the customer is located.',
#     'Description': 'A string that represents a sub-national entity within which customers reside. This field may not be applicable for all countries and can have missing values in some records.',
#     'Relationships with other columns': 'This column provides additional geographical detail when combined with city, postalCode, and country to form the complete address of each customer record.',
#     'Sample value': 'NV'},
#    {'Column': 'postalCode',
#     'Possible meaning': "The postal or zip code for the customer's location.",
#     'Description': 'A string that represents a set of numbers or letters used by postal services to sort mail. It is part of the address information and can be unique within a country.',
#     'Relationships with other columns': 'This column is often analyzed alongside city, state, and country to provide precise geographical location data for each customer record.',
#     'Sample value': '44000'},
#    {'Column': 'country',
#     'Possible meaning': "The name of the country where the customer's business or individual account is located.",
#     'Description': 'A string that represents a sovereign state within which customers reside. It provides high-level geographical context for each record in the dataset.',
#     'Relationships with other columns': 'This column can be used together with city, state (if applicable), and postalCode to form complete address information for customer records.',
#     'Sample value': 'France'},
#    {'Column': 'salesRepEmployeeNumber',
#     'Possible meaning': 'The unique identifier of the sales representative assigned to this customer account.',
#     'Description': "An integer that uniquely identifies a specific employee who is responsible for managing and servicing this particular customer's business or individual account.",
#     'Relationships with other columns': 'This column can be used in conjunction with contactLastName, contactFirstName, and possibly additional information about the sales representative to understand which employees are handling different customers.',
#     'Sample value': 1370},
#    {'Column': 'creditLimit',
#     'Possible meaning': 'The maximum amount of credit that a customer can use before needing further approval or payment.',
#     'Description': 'A floating-point number representing the upper limit on how much money a business is willing to extend as credit to this specific customer without additional review.',
#     'Relationships with other columns': 'This column may be analyzed alongside salesRepEmployeeNumber and possibly order data to understand financial risk management practices for different customers.',
#     'Sample value': 21000.0}]},
#  {'Data Dictionary for employee.csv': [{'Column': 'employeeNumber',
#     'Possible meaning': 'Unique identifier assigned to each employee.',
#     'Description': "A unique integer value that identifies an individual employee within the company's database.",
#     'Relationships with other columns': "This column can be used as a foreign key in related tables, such as sales or performance metrics. It may also relate to 'reportsTo' indicating who reports to whom.",
#     'Sample value': 1002},
#    {'Column': 'lastName',
#     'Possible meaning': 'Last name of the employee.',
#     'Description': 'The family name or surname of an individual employee, used for identification and communication purposes within the company.',
#     'Relationships with other columns': "Often paired with 'firstName' to form a complete personal identifier. Can be combined with 'employeeNumber' in reports or directories.",
#     'Sample value': 'Murphy'},
#    {'Column': 'firstName',
#     'Possible meaning': 'First name of the employee.',
#     'Description': 'The given name or first name of an individual employee, used for identification and communication purposes within the company.',
#     'Relationships with other columns': "Often paired with 'lastName' to form a complete personal identifier. Can be combined with 'employeeNumber' in reports or directories.",
#     'Sample value': 'Diane'},
#    {'Column': 'extension',
#     'Possible meaning': "Phone extension number of the employee's office phone.",
#     'Description': "A short code used to connect calls directly to an individual employee’s desk within a company's internal telephone system.",
#     'Relationships with other columns': '',
#     'Sample value': 'x5800'},
#    {'Column': 'email',
#     'Possible meaning': 'Email address of the employee.',
#     'Description': 'The electronic mail identifier used by an individual employee for official communication within and outside the company.',
#     'Relationships with other columns': '',
#     'Sample value': 'dmurphy@classicmodelcars.com'},
#    {'Column': 'officeCode',
#     'Possible meaning': 'Identifier of the office where the employee works.',
#     'Description': "A unique code that represents a specific physical location or branch within the company's network, indicating where an individual employee is based.",
#     'Relationships with other columns': '',
#     'Sample value': 1},
#    {'Column': 'reportsTo',
#     'Possible meaning': 'Employee number of the supervisor to whom this employee reports.',
#     'Description': 'The unique identifier (employeeNumber) of an individual who is in a supervisory role over another employee, indicating hierarchical relationships within the company structure.',
#     'Relationships with other columns': '',
#     'Sample value': 0},
#    {'Column': 'jobTitle',
#     'Possible meaning': 'Job title or position held by the employee.',
#     'Description': "The official designation of an individual's role, responsibilities, and level within the company hierarchy.",
#     'Relationships with other columns': '',
#     'Sample value': 'President'}]},
#  {'Data Dictionary for office.csv': [{'Column': 'officeCode',
#     'Possible meaning': 'Unique identifier for each office.',
#     'Description': "An integer that uniquely identifies an office within a company's database or system.",
#     'Relationships with other columns': 'This column is likely the primary key and can be used to join this table with others where offices are referenced by their code, such as employee assignments or sales territories.',
#     'Sample value': 1},
#    {'Column': 'city',
#     'Possible meaning': 'The city in which an office is located.',
#     'Description': 'A string that represents the name of a city. This information can be used to understand where each office is situated geographically.',
#     'Relationships with other columns': "This column often correlates with 'state' and 'country', providing geographical context for the address.",
#     'Sample value': 'San Francisco'},
#    {'Column': 'phone',
#     'Possible meaning': 'The telephone number of an office.',
#     'Description': 'A string that contains a phone number, including country code. This is used to contact the office directly.',
#     'Relationships with other columns': '',
#     'Sample value': '+1 650 219 4782'},
#    {'Column': 'addressLine1',
#     'Possible meaning': 'The first line of an address for an office location.',
#     'Description': 'A string that represents the primary street or building name and number where the office is located. This information can be used in conjunction with other address fields to provide a complete mailing address.',
#     'Relationships with other columns': "This column, along with 'addressLine2', 'city', 'state', 'country', and 'postalCode' form a full postal address for each office location.",
#     'Sample value': '100 Market Street'},
#    {'Column': 'addressLine2',
#     'Possible meaning': 'The second line of an address, typically used to specify suite or building details.',
#     'Description': 'A string that provides additional information about the physical location within a larger structure (e.g., Suite number). This field is optional and may be null for some entries.',
#     'Relationships with other columns': "This column complements 'addressLine1' in providing more detailed address information. It can be combined with other address fields to form a complete mailing address.",
#     'Sample value': 'Suite 300'},
#    {'Column': 'state',
#     'Possible meaning': 'The state or province where an office is located within the country.',
#     'Description': 'A string that represents the name of a state, region, or province. This information can be used to understand regional distribution of offices and for compliance with local laws.',
#     'Relationships with other columns': "This column often correlates with 'city' and 'country', providing geographical context for the address.",
#     'Sample value': 'CA'},
#    {'Column': 'country',
#     'Possible meaning': 'The country where an office is located.',
#     'Description': 'A string that represents a nation or sovereign state. This information can be used to understand international distribution of offices and for compliance with local laws.',
#     'Relationships with other columns': "This column often correlates with 'city', 'state' (if applicable), providing geographical context for the address.",
#     'Sample value': 'USA'},
#    {'Column': 'postalCode',
#     'Possible meaning': "The postal or zip code of an office's location.",
#     'Description': 'A string that represents a set of numbers and/or letters used by postal services to sort mail. This information can be used for accurate delivery addresses.',
#     'Relationships with other columns': "This column, along with 'addressLine1', 'city', 'state' (if applicable), and 'country' form a complete mailing address.",
#     'Sample value': '94080'},
#    {'Column': 'territory',
#     'Possible meaning': 'The sales or administrative territory to which an office belongs.',
#     'Description': 'A string that represents the larger region or area under which the office operates. This can be used for organizational and reporting purposes, such as EMEA (Europe, Middle East & Africa).',
#     'Relationships with other columns': '',
#     'Sample value': 'EMEA'}]},
#  {'Data Dictionary for orderdetails.csv': [{'Column': 'orderNumber',
#     'Possible meaning': 'A unique identifier assigned to each order.',
#     'Description': 'This column contains a numeric code that uniquely identifies an individual order placed by a customer or client.',
#     'Relationships with other columns': "It is likely related to the orders table where more details about the specific order can be found. It may also relate directly to 'quantityOrdered' and 'priceEach', as these values are associated with each unique order number.",
#     'Sample value': 10100},
#    {'Column': 'productCode',
#     'Possible meaning': 'A code that uniquely identifies a product within the inventory or catalog of products offered by the company.',
#     'Description': 'This column contains alphanumeric codes representing different products. These are likely linked to another table containing detailed information about each product, such as its name and description.',
#     'Relationships with other columns': "It is related to 'quantityOrdered' and 'priceEach', which provide details on how much of a particular product was ordered and at what price per unit.",
#     'Sample value': 'S18_1749'},
#    {'Column': 'quantityOrdered',
#     'Possible meaning': 'The number of units of the specified product that were included in an order.',
#     'Description': 'This column contains integer values representing how many items of a particular product code have been ordered by customers for each specific order.',
#     'Relationships with other columns': "It is directly related to 'productCode' and can be used together with 'priceEach' to calculate the total cost per item or overall order value.",
#     'Sample value': 30},
#    {'Column': 'priceEach',
#     'Possible meaning': 'The price at which each unit of a product was sold in an individual transaction.',
#     'Description': 'This column contains floating-point numbers representing the selling price per unit for products included in orders. The prices can vary based on different factors such as discounts or promotions.',
#     'Relationships with other columns': "It is related to 'quantityOrdered' and together they help determine the total cost of each product within an order, which could be used to calculate overall order value when combined with 'orderNumber'.",
#     'Sample value': 136.0},
#    {'Column': 'orderLineNumber',
#     'Possible meaning': 'A sequential number indicating the position or line item in a given order.',
#     'Description': 'This column contains integer values that represent the sequence of items within an individual order, starting from 1 and incrementing for each additional product included in the same order.',
#     'Relationships with other columns': "It is related to 'orderNumber', as it specifies which line item (product) corresponds to a specific position within an overall order. It can be used together with 'quantityOrdered' and 'priceEach' to analyze individual items within orders.",
#     'Sample value': 3}]},
#  {'Data Dictionary for orders.csv': [{'Column': 'orderNumber',
#     'Possible meaning': 'Unique identifier for each order.',
#     'Description': 'An integer that uniquely identifies an individual order within the dataset.',
#     'Relationships with other columns': 'Can be used to link this table with others, such as order details or customer information tables. It is unique and does not repeat in the dataset.',
#     'Sample value': 10100},
#    {'Column': 'orderDate',
#     'Possible meaning': 'The date when an order was placed by a customer.',
#     'Description': "A string representing the date of placing each order, formatted as 'YYYY-MM-DD'.",
#     'Relationships with other columns': 'Can be compared against requiredDate and shippedDate to determine how quickly orders are processed. It helps in analyzing the time taken for an order from placement until it is shipped or marked as completed.',
#     'Sample value': '2003-01-06'},
#    {'Column': 'requiredDate',
#     'Possible meaning': 'The date by which a customer expects their order to be delivered.',
#     'Description': "A string representing the expected delivery date of each order, formatted as 'YYYY-MM-DD'. This is usually set by customers or sales representatives based on when they need the products.",
#     'Relationships with other columns': 'Can be compared against shippedDate and status to determine if orders are being delivered within the required timeframe. It helps in assessing customer satisfaction levels regarding delivery times.',
#     'Sample value': '2003-01-13'},
#    {'Column': 'shippedDate',
#     'Possible meaning': 'The date when an order was shipped out to a customer.',
#     'Description': "A string representing the actual shipping date of each order, formatted as 'YYYY-MM-DD'. This is set once the products are dispatched from the warehouse or store.",
#     'Relationships with other columns': 'Can be compared against requiredDate and status to determine if orders were shipped on time. It helps in tracking logistics efficiency and customer satisfaction.',
#     'Sample value': '2003-01-10'},
#    {'Column': 'status',
#     'Possible meaning': "The current state of an order, such as 'Shipped', 'Cancelled', etc.",
#     'Description': 'A string representing the status or stage that each order is in. This can include states like Shipped, Cancelled, On Hold, and more.',
#     'Relationships with other columns': 'Can be used to analyze trends over time by comparing it against shippedDate and requiredDate. It helps in understanding the flow of orders through different stages from placement until completion or cancellation.',
#     'Sample value': 'Shipped'},
#    {'Column': 'comments',
#     'Possible meaning': 'Additional notes about an order, such as special requests or issues encountered during processing.',
#     'Description': 'A string containing any additional comments related to the orders. This can include customer-specific instructions, internal remarks from staff members, etc.',
#     'Relationships with other columns': 'Can provide context for understanding specific statuses or delays in shippedDate compared to orderDate and requiredDate. It helps in identifying issues that may affect delivery times or customer satisfaction.',
#     'Sample value': 'Check on availability.'},
#    {'Column': 'customerNumber',
#     'Possible meaning': 'Unique identifier for each customer who placed an order.',
#     'Description': 'An integer representing a unique identifier assigned to customers. This can be used to link orders back to specific customers and analyze their purchasing behavior over time.',
#     'Relationships with other columns': 'Can be linked with external tables containing customer information, such as name or contact details. It helps in identifying repeat customers and analyzing order patterns per customer.',
#     'Sample value': 363}]},
#  {'Data Dictionary for payments.csv': [{'Column': 'customerNumber',
#     'Possible meaning': 'Unique identifier for each customer.',
#     'Description': 'An integer value that uniquely identifies a specific customer within the dataset.',
#     'Relationships with other columns': 'This column could be used to link payment records back to individual customers, possibly correlating with data in another table or file containing detailed customer information.',
#     'Sample value': 103},
#    {'Column': 'checkNumber',
#     'Possible meaning': 'Unique identifier for each check/payment transaction.',
#     'Description': 'A string that uniquely identifies a payment made by the customer, likely used to track individual transactions or checks.',
#     'Relationships with other columns': "This column could be related to 'paymentDate' and 'amount', as it represents an instance of a specific amount being paid on a certain date.",
#     'Sample value': 'HQ336336'},
#    {'Column': 'paymentDate',
#     'Possible meaning': 'The date when the payment was made or processed.',
#     'Description': "A string representing the date in 'YYYY-MM-DD' format, indicating on which day a particular transaction occurred.",
#     'Relationships with other columns': "This column is likely to be analyzed alongside 'amount', as it provides context for when payments of specific amounts were made. It could also correlate with customer payment patterns over time.",
#     'Sample value': '2004-10-19'},
#    {'Column': 'amount',
#     'Possible meaning': 'The monetary amount paid in a transaction.',
#     'Description': 'A floating point number representing the total sum of money that was transferred or paid for each record.',
#     'Relationships with other columns': "This column is directly related to 'checkNumber' and 'paymentDate', as it specifies how much was paid on what date through which check. It could also be analyzed in conjunction with 'customerNumber' to understand payment behavior per customer.",
#     'Sample value': 6066.78}]},
#  {'Data Dictionary for productlines.csv': [{'Column': 'productLine',
#     'Possible meaning': 'Category or type of products available.',
#     'Description': 'This column lists different categories or lines of products such as Classic Cars, Motorcycles etc., which are offered by the company.',
#     'Relationships with other columns': "It could be related to 'textDescription' and potentially used in conjunction with sales data from another file to analyze product line performance.",
#     'Sample value': 'Classic Cars'},
#    {'Column': 'textDescription',
#     'Possible meaning': 'Detailed textual description of the product line.',
#     'Description': 'This column contains detailed descriptions for each product line, providing information about features and characteristics of products within that category.',
#     'Relationships with other columns': "It is directly related to 'productLine' as it provides a more in-depth explanation of what each product line entails.",
#     'Sample value': 'Attention car enthusiasts: Make your wildest car ownership dreams come true. Whether you are looking for classic muscle cars, dream sports cars or movie-inspired miniatures, you will find great choices in this category...'},
#    {'Column': 'htmlDescription',
#     'Possible meaning': 'HTML formatted description of the product line.',
#     'Description': 'This column is intended to hold HTML-formatted descriptions for each product line. However, all values are null indicating that no data has been populated here yet.',
#     'Relationships with other columns': "It should be related to 'productLine' and potentially replace or complement 'textDescription', but currently holds no usable information.",
#     'Sample value': 'None'},
#    {'Column': 'image',
#     'Possible meaning': 'Image associated with the product line.',
#     'Description': "This column is intended for storing image references (like URLs) related to each product line. Similar to 'htmlDescription', all values are null, indicating no images have been linked or uploaded yet.",
#     'Relationships with other columns': "It should be related to 'productLine' and could complement the textual descriptions in 'textDescription'. However, currently holds no usable information.",
#     'Sample value': 'None'}]},
#  {'Data Dictionary for products.csv': [{'Column': 'productCode',
#     'Possible meaning': 'Unique identifier for each product.',
#     'Description': 'A code assigned to uniquely identify a specific product within the inventory or catalog system.',
#     'Relationships with other columns': 'This column is likely used as a primary key and could be related to sales data, stock levels, etc., in other datasets.',
#     'Sample value': 'S10_1678'},
#    {'Column': 'productName',
#     'Possible meaning': 'The name of the product.',
#     'Description': 'A descriptive name given to a specific product that helps identify it among others. It usually reflects what the item is or its brand and model.',
#     'Relationships with other columns': "It can be associated with 'productLine' for categorization purposes, and 'productCode' as an identifier.",
#     'Sample value': '1969 Harley Davidson Ultimate Chopper'},
#    {'Column': 'productLine',
#     'Possible meaning': 'The category or line of products to which the product belongs.',
#     'Description': 'A classification that groups similar types of products together, such as Motorcycles, Classic Cars, etc., for easier management and analysis.',
#     'Relationships with other columns': "It is related to 'productName' in terms of categorization. It can also be used to analyze sales or inventory trends by product category.",
#     'Sample value': 'Motorcycles'},
#    {'Column': 'productScale',
#     'Possible meaning': 'The scale at which the product is made, typically for models and replicas.',
#     'Description': "Indicates how much smaller a model replica is compared to its real-life counterpart. For example, '1:10' means that every unit of measurement on the model represents 10 units in reality.",
#     'Relationships with other columns': "It can be related to 'productName', especially if it's a scale model or toy product.",
#     'Sample value': '1:10'},
#    {'Column': 'productVendor',
#     'Possible meaning': 'The vendor or manufacturer of the product.',
#     'Description': 'Identifies who produces, manufactures, or supplies the products to the store. This can be a company name or brand.',
#     'Relationships with other columns': "It is related to 'productName' and could also be used for supplier analysis in conjunction with sales data.",
#     'Sample value': 'Min Lin Diecast'},
#    {'Column': 'productDescription',
#     'Possible meaning': "A detailed description of the product's features, specifications, or characteristics.",
#     'Description': 'Provides a comprehensive overview of what the product is and its key attributes. This can be used for marketing purposes or to inform customers about the product details.',
#     'Relationships with other columns': "It complements 'productName' by providing more detailed information on each item.",
#     'Sample value': 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.'},
#    {'Column': 'quantityInStock',
#     'Possible meaning': 'The number of units currently in stock.',
#     'Description': 'Represents the current inventory level for a specific product indicating how many items are available for sale or distribution.',
#     'Relationships with other columns': "It can be analyzed alongside 'buyPrice' and 'MSRP' to determine profitability, as well as sales data to track inventory turnover rates.",
#     'Sample value': 7933},
#    {'Column': 'buyPrice',
#     'Possible meaning': 'The price at which the product was purchased from a vendor or supplier.',
#     'Description': 'Represents the cost incurred by the business for each unit of the product. This is crucial for calculating profit margins and managing costs.',
#     'Relationships with other columns': "It can be compared to 'MSRP' to determine gross margin, and analyzed alongside 'quantityInStock' for inventory valuation purposes.",
#     'Sample value': 48.81},
#    {'Column': 'MSRP',
#     'Possible meaning': "Manufacturer's Suggested Retail Price.",
#     'Description': 'The recommended retail price set by the manufacturer at which retailers are advised to sell their products, although it can vary based on market conditions and retailer policies.',
#     'Relationships with other columns': "It is used in conjunction with 'buyPrice' for profit margin analysis. It also influences pricing strategies alongside 'quantityInStock'.",
#     'Sample value': 95.7}]}]

# %%
prompt = """<Data_Dictionary_Analytics_Suggester>
    
    <purpose>
        Analyze provided data dictionaries comprehensively to identify column relationships and suggest a wide range of potential analytics use cases that leverage these relationships to generate meaningful and actionable business insights.
    </purpose>
    
    <instructions>
        1. **Review** all provided data dictionaries thoroughly, ensuring no dataset or column is overlooked.
        2. **Examine** each dataset's columns, their meanings, descriptions, and existing relationships in detail.
        3. **Identify** all meaningful relationships and combinations of columns within the same dataset and across different datasets that can be leveraged for insightful analysis.
        4. **Ensure** that every dataset and its relevant columns are considered to maximize the utilization of available data.
        5. **Brainstorm** a diverse range of potential analytics use cases that utilize these column relationships to address various business objectives such as improving sales, optimizing inventory, understanding customer behavior, enhancing operational efficiency, etc.
        6. **For each suggested use case**, provide a detailed explanation of how specific column combinations and their relationships contribute to the insights.
        7. **Ensure** that all suggested use cases are actionable, relevant, and based solely on the information provided in the data dictionaries without incorporating any external knowledge or assumptions.
        8. **Summarize** key relationships between datasets that underpin the proposed analytics use cases, ensuring that cross-dataset relationships are highlighted and utilized.
    </instructions>
    
    <output_format>
        For each identified analytics use case, provide the following structured information:
        
        ```
        ### Use Case <Number>
        - **Use Case ID:** UC<UniqueNumber>
        - **Title:** <Descriptive Title of the Use Case>
        - **Description:** <Detailed explanation of the analytics use case, including the business objective it addresses and the insights it aims to generate.>
        - **Data Sources:**
            - <Dataset1.csv>
            - <Dataset2.csv>
            - <!-- Add additional data sources as needed -->
        - **Columns Utilized:**
            - <Dataset1.csv>.<ColumnName>
            - <Dataset2.csv>.<ColumnName>
            - <!-- List all relevant columns from the respective datasets -->
        - **Relationships Leveraged:**
            - <Description of how the columns are related (e.g., primary key, foreign key, common attributes) and how these relationships are utilized in the analysis.>
        
        ---
        ```
        
        **Example:**
        
        ```
        ### Use Case 1
        - **Use Case ID:** UC001
        - **Title:** Inventory Optimization Based on Product Categories
        - **Description:** Analyze the `quantityInStock` in relation to `productLine` and `buyPrice` to identify overstocked or understocked categories, enabling better inventory management and cost optimization.
        - **Data Sources:**
            - products.csv
            - productlines.csv
        - **Columns Utilized:**
            - products.csv.quantityInStock
            - products.csv.buyPrice
            - products.csv.productLine
            - productlines.csv.productLine
        - **Relationships Leveraged:**
            - The `productLine` column in `products.csv` is related to the `productLine` column in `productlines.csv`, allowing categorization of inventory levels by product category.
        
        ---
        ```
    </output_format>
    
    <rules>
        1. **Exact Naming:** Use the exact table and column names as specified in the provided data dictionaries.
        2. **Relevance:** Only suggest analytics use cases that are directly supported by the relationships and data available in the data dictionaries.
        3. **Actionable Use Cases:** Ensure that each use case is actionable and aligned with common business objectives such as improving sales, optimizing inventory, understanding customer behavior, enhancing operational efficiency, etc.
        4. **Comprehensive Utilization:** Actively utilize as many datasets and columns as possible, ensuring that no relevant data is left unexplored or unused in the suggested use cases.
        5. **Clarity:** Provide clear and concise descriptions for each use case, avoiding ambiguity and ensuring that the purpose and methodology are easily understandable.
        6. **Structured Output:** Adhere strictly to the specified output format to maintain consistency and ease of interpretation across all suggested use cases.
        7. **No Assumptions:** Base all suggestions solely on the provided data dictionaries without introducing external information or making assumptions beyond the given data.
        8. **Unique Identification:** Assign a unique ID to each use case to facilitate easy reference and tracking.
        9. **Avoid Redundancy:** Ensure that each use case is unique and does not duplicate the purpose or methodology of another use case.
        10. **Cross-Dataset Relationships:** Actively seek and leverage relationships across different datasets to create comprehensive and insightful use cases that span multiple areas of the business.
    </rules>
    
</Data_Dictionary_Analytics_Suggester>"""

# %%
# Construct a list of TextMessage as prompt
# Combine data dict ingestion agent prompt with all previous responses
initial_task = [TextMessage(content=f"Review the data dictionary generated by the file handling agents.",source="user")]
responses_TextMessage.extend(initial_task)

# %%
responses_TextMessage
# Out:
# [{'Data Dictionary for customer.csv': [{'Column': 'customerNumber',
#     'Possible meaning': 'Unique identifier for each customer.',
#     'Description': 'An integer that uniquely identifies a specific customer record within the dataset.',
#     'Relationships with other columns': 'This column is likely to be used as a foreign key in related tables such as orders or payments.',
#     'Sample value': 103},
#    {'Column': 'customerName',
#     'Possible meaning': "The name of the customer's company or individual.",
#     'Description': 'A string that represents the full name of the customer, which could be a business entity or an individual person.',
#     'Relationships with other columns': 'This column is often used in conjunction with contactLastName and contactFirstName to identify specific contacts within a customer record.',
#     'Sample value': 'Atelier graphique'},
#    {'Column': 'contactLastName',
#     'Possible meaning': 'The last name of the primary contact person for this customer.',
#     'Description': "A string that contains the surname or family name of the main point of contact at a customer's business or individual account.",
#     'Relationships with other columns': 'This column is often used together with contactFirstName to form full names and can be linked with salesRepEmployeeNumber if there are specific representatives assigned per last name basis.',
#     'Sample value': 'Schmitt'},
#    {'Column': 'contactFirstName',
#     'Possible meaning': 'The first name of the primary contact person for this customer.',
#     'Description': "A string that contains the given or personal name of the main point of contact at a customer's business or individual account.",
#     'Relationships with other columns': 'This column is often used together with contactLastName to form full names and can be linked with salesRepEmployeeNumber if there are specific representatives assigned per first name basis.',
#     'Sample value': 'Carine'},
#    {'Column': 'phone',
#     'Possible meaning': "The primary phone number for the customer's business or individual account.",
#     'Description': 'A string that contains a telephone number used to contact the customer. The format may vary by country and region.',
#     'Relationships with other columns': 'This column is often analyzed alongside addressLine1, city, state, postalCode, and country to provide comprehensive contact information for customers.',
#     'Sample value': '40.32.2555'},
#    {'Column': 'addressLine1',
#     'Possible meaning': "The first line of the customer's physical address.",
#     'Description': 'A string that contains part of a street address, often including house number and name or type of road.',
#     'Relationships with other columns': 'This column is typically used in conjunction with addressLine2 (if available), city, state, postalCode, and country to form the full mailing address for customers.',
#     'Sample value': '54, rue Royale'},
#    {'Column': 'addressLine2',
#     'Possible meaning': "The second line of the customer's physical address. This could include suite number or building name.",
#     'Description': 'A string that contains additional information about a street address such as an apartment number or floor level, but it is not always provided for every record.',
#     'Relationships with other columns': "This column complements addressLine1 and can be used together to provide more detailed location data. It's often analyzed alongside city, state, postalCode, and country.",
#     'Sample value': 'Level 3'},
#    {'Column': 'city',
#     'Possible meaning': 'The name of the city where the customer is located.',
#     'Description': "A string that represents a locality within which customers reside or conduct business. It's an essential part of their address information.",
#     'Relationships with other columns': 'This column is often used together with state, postalCode, and country to provide full geographical context for each record in the dataset.',
#     'Sample value': 'Nantes'},
#    {'Column': 'state',
#     'Possible meaning': 'The name or abbreviation of the administrative division (e.g., province, county) where the customer is located.',
#     'Description': 'A string that represents a sub-national entity within which customers reside. This field may not be applicable for all countries and can have missing values in some records.',
#     'Relationships with other columns': 'This column provides additional geographical detail when combined with city, postalCode, and country to form the complete address of each customer record.',
#     'Sample value': 'NV'},
#    {'Column': 'postalCode',
#     'Possible meaning': "The postal or zip code for the customer's location.",
#     'Description': 'A string that represents a set of numbers or letters used by postal services to sort mail. It is part of the address information and can be unique within a country.',
#     'Relationships with other columns': 'This column is often analyzed alongside city, state, and country to provide precise geographical location data for each customer record.',
#     'Sample value': '44000'},
#    {'Column': 'country',
#     'Possible meaning': "The name of the country where the customer's business or individual account is located.",
#     'Description': 'A string that represents a sovereign state within which customers reside. It provides high-level geographical context for each record in the dataset.',
#     'Relationships with other columns': 'This column can be used together with city, state (if applicable), and postalCode to form complete address information for customer records.',
#     'Sample value': 'France'},
#    {'Column': 'salesRepEmployeeNumber',
#     'Possible meaning': 'The unique identifier of the sales representative assigned to this customer account.',
#     'Description': "An integer that uniquely identifies a specific employee who is responsible for managing and servicing this particular customer's business or individual account.",
#     'Relationships with other columns': 'This column can be used in conjunction with contactLastName, contactFirstName, and possibly additional information about the sales representative to understand which employees are handling different customers.',
#     'Sample value': 1370},
#    {'Column': 'creditLimit',
#     'Possible meaning': 'The maximum amount of credit that a customer can use before needing further approval or payment.',
#     'Description': 'A floating-point number representing the upper limit on how much money a business is willing to extend as credit to this specific customer without additional review.',
#     'Relationships with other columns': 'This column may be analyzed alongside salesRepEmployeeNumber and possibly order data to understand financial risk management practices for different customers.',
#     'Sample value': 21000.0}]},
#  {'Data Dictionary for employee.csv': [{'Column': 'employeeNumber',
#     'Possible meaning': 'Unique identifier assigned to each employee.',
#     'Description': "A unique integer value that identifies an individual employee within the company's database.",
#     'Relationships with other columns': "This column can be used as a foreign key in related tables, such as sales or performance metrics. It may also relate to 'reportsTo' indicating who reports to whom.",
#     'Sample value': 1002},
#    {'Column': 'lastName',
#     'Possible meaning': 'Last name of the employee.',
#     'Description': 'The family name or surname of an individual employee, used for identification and communication purposes within the company.',
#     'Relationships with other columns': "Often paired with 'firstName' to form a complete personal identifier. Can be combined with 'employeeNumber' in reports or directories.",
#     'Sample value': 'Murphy'},
#    {'Column': 'firstName',
#     'Possible meaning': 'First name of the employee.',
#     'Description': 'The given name or first name of an individual employee, used for identification and communication purposes within the company.',
#     'Relationships with other columns': "Often paired with 'lastName' to form a complete personal identifier. Can be combined with 'employeeNumber' in reports or directories.",
#     'Sample value': 'Diane'},
#    {'Column': 'extension',
#     'Possible meaning': "Phone extension number of the employee's office phone.",
#     'Description': "A short code used to connect calls directly to an individual employee’s desk within a company's internal telephone system.",
#     'Relationships with other columns': '',
#     'Sample value': 'x5800'},
#    {'Column': 'email',
#     'Possible meaning': 'Email address of the employee.',
#     'Description': 'The electronic mail identifier used by an individual employee for official communication within and outside the company.',
#     'Relationships with other columns': '',
#     'Sample value': 'dmurphy@classicmodelcars.com'},
#    {'Column': 'officeCode',
#     'Possible meaning': 'Identifier of the office where the employee works.',
#     'Description': "A unique code that represents a specific physical location or branch within the company's network, indicating where an individual employee is based.",
#     'Relationships with other columns': '',
#     'Sample value': 1},
#    {'Column': 'reportsTo',
#     'Possible meaning': 'Employee number of the supervisor to whom this employee reports.',
#     'Description': 'The unique identifier (employeeNumber) of an individual who is in a supervisory role over another employee, indicating hierarchical relationships within the company structure.',
#     'Relationships with other columns': '',
#     'Sample value': 0},
#    {'Column': 'jobTitle',
#     'Possible meaning': 'Job title or position held by the employee.',
#     'Description': "The official designation of an individual's role, responsibilities, and level within the company hierarchy.",
#     'Relationships with other columns': '',
#     'Sample value': 'President'}]},
#  {'Data Dictionary for office.csv': [{'Column': 'officeCode',
#     'Possible meaning': 'Unique identifier for each office.',
#     'Description': "An integer that uniquely identifies an office within a company's database or system.",
#     'Relationships with other columns': 'This column is likely the primary key and can be used to join this table with others where offices are referenced by their code, such as employee assignments or sales territories.',
#     'Sample value': 1},
#    {'Column': 'city',
#     'Possible meaning': 'The city in which an office is located.',
#     'Description': 'A string that represents the name of a city. This information can be used to understand where each office is situated geographically.',
#     'Relationships with other columns': "This column often correlates with 'state' and 'country', providing geographical context for the address.",
#     'Sample value': 'San Francisco'},
#    {'Column': 'phone',
#     'Possible meaning': 'The telephone number of an office.',
#     'Description': 'A string that contains a phone number, including country code. This is used to contact the office directly.',
#     'Relationships with other columns': '',
#     'Sample value': '+1 650 219 4782'},
#    {'Column': 'addressLine1',
#     'Possible meaning': 'The first line of an address for an office location.',
#     'Description': 'A string that represents the primary street or building name and number where the office is located. This information can be used in conjunction with other address fields to provide a complete mailing address.',
#     'Relationships with other columns': "This column, along with 'addressLine2', 'city', 'state', 'country', and 'postalCode' form a full postal address for each office location.",
#     'Sample value': '100 Market Street'},
#    {'Column': 'addressLine2',
#     'Possible meaning': 'The second line of an address, typically used to specify suite or building details.',
#     'Description': 'A string that provides additional information about the physical location within a larger structure (e.g., Suite number). This field is optional and may be null for some entries.',
#     'Relationships with other columns': "This column complements 'addressLine1' in providing more detailed address information. It can be combined with other address fields to form a complete mailing address.",
#     'Sample value': 'Suite 300'},
#    {'Column': 'state',
#     'Possible meaning': 'The state or province where an office is located within the country.',
#     'Description': 'A string that represents the name of a state, region, or province. This information can be used to understand regional distribution of offices and for compliance with local laws.',
#     'Relationships with other columns': "This column often correlates with 'city' and 'country', providing geographical context for the address.",
#     'Sample value': 'CA'},
#    {'Column': 'country',
#     'Possible meaning': 'The country where an office is located.',
#     'Description': 'A string that represents a nation or sovereign state. This information can be used to understand international distribution of offices and for compliance with local laws.',
#     'Relationships with other columns': "This column often correlates with 'city', 'state' (if applicable), providing geographical context for the address.",
#     'Sample value': 'USA'},
#    {'Column': 'postalCode',
#     'Possible meaning': "The postal or zip code of an office's location.",
#     'Description': 'A string that represents a set of numbers and/or letters used by postal services to sort mail. This information can be used for accurate delivery addresses.',
#     'Relationships with other columns': "This column, along with 'addressLine1', 'city', 'state' (if applicable), and 'country' form a complete mailing address.",
#     'Sample value': '94080'},
#    {'Column': 'territory',
#     'Possible meaning': 'The sales or administrative territory to which an office belongs.',
#     'Description': 'A string that represents the larger region or area under which the office operates. This can be used for organizational and reporting purposes, such as EMEA (Europe, Middle East & Africa).',
#     'Relationships with other columns': '',
#     'Sample value': 'EMEA'}]},
#  {'Data Dictionary for orderdetails.csv': [{'Column': 'orderNumber',
#     'Possible meaning': 'A unique identifier assigned to each order.',
#     'Description': 'This column contains a numeric code that uniquely identifies an individual order placed by a customer or client.',
#     'Relationships with other columns': "It is likely related to the orders table where more details about the specific order can be found. It may also relate directly to 'quantityOrdered' and 'priceEach', as these values are associated with each unique order number.",
#     'Sample value': 10100},
#    {'Column': 'productCode',
#     'Possible meaning': 'A code that uniquely identifies a product within the inventory or catalog of products offered by the company.',
#     'Description': 'This column contains alphanumeric codes representing different products. These are likely linked to another table containing detailed information about each product, such as its name and description.',
#     'Relationships with other columns': "It is related to 'quantityOrdered' and 'priceEach', which provide details on how much of a particular product was ordered and at what price per unit.",
#     'Sample value': 'S18_1749'},
#    {'Column': 'quantityOrdered',
#     'Possible meaning': 'The number of units of the specified product that were included in an order.',
#     'Description': 'This column contains integer values representing how many items of a particular product code have been ordered by customers for each specific order.',
#     'Relationships with other columns': "It is directly related to 'productCode' and can be used together with 'priceEach' to calculate the total cost per item or overall order value.",
#     'Sample value': 30},
#    {'Column': 'priceEach',
#     'Possible meaning': 'The price at which each unit of a product was sold in an individual transaction.',
#     'Description': 'This column contains floating-point numbers representing the selling price per unit for products included in orders. The prices can vary based on different factors such as discounts or promotions.',
#     'Relationships with other columns': "It is related to 'quantityOrdered' and together they help determine the total cost of each product within an order, which could be used to calculate overall order value when combined with 'orderNumber'.",
#     'Sample value': 136.0},
#    {'Column': 'orderLineNumber',
#     'Possible meaning': 'A sequential number indicating the position or line item in a given order.',
#     'Description': 'This column contains integer values that represent the sequence of items within an individual order, starting from 1 and incrementing for each additional product included in the same order.',
#     'Relationships with other columns': "It is related to 'orderNumber', as it specifies which line item (product) corresponds to a specific position within an overall order. It can be used together with 'quantityOrdered' and 'priceEach' to analyze individual items within orders.",
#     'Sample value': 3}]},
#  {'Data Dictionary for orders.csv': [{'Column': 'orderNumber',
#     'Possible meaning': 'Unique identifier for each order.',
#     'Description': 'An integer that uniquely identifies an individual order within the dataset.',
#     'Relationships with other columns': 'Can be used to link this table with others, such as order details or customer information tables. It is unique and does not repeat in the dataset.',
#     'Sample value': 10100},
#    {'Column': 'orderDate',
#     'Possible meaning': 'The date when an order was placed by a customer.',
#     'Description': "A string representing the date of placing each order, formatted as 'YYYY-MM-DD'.",
#     'Relationships with other columns': 'Can be compared against requiredDate and shippedDate to determine how quickly orders are processed. It helps in analyzing the time taken for an order from placement until it is shipped or marked as completed.',
#     'Sample value': '2003-01-06'},
#    {'Column': 'requiredDate',
#     'Possible meaning': 'The date by which a customer expects their order to be delivered.',
#     'Description': "A string representing the expected delivery date of each order, formatted as 'YYYY-MM-DD'. This is usually set by customers or sales representatives based on when they need the products.",
#     'Relationships with other columns': 'Can be compared against shippedDate and status to determine if orders are being delivered within the required timeframe. It helps in assessing customer satisfaction levels regarding delivery times.',
#     'Sample value': '2003-01-13'},
#    {'Column': 'shippedDate',
#     'Possible meaning': 'The date when an order was shipped out to a customer.',
#     'Description': "A string representing the actual shipping date of each order, formatted as 'YYYY-MM-DD'. This is set once the products are dispatched from the warehouse or store.",
#     'Relationships with other columns': 'Can be compared against requiredDate and status to determine if orders were shipped on time. It helps in tracking logistics efficiency and customer satisfaction.',
#     'Sample value': '2003-01-10'},
#    {'Column': 'status',
#     'Possible meaning': "The current state of an order, such as 'Shipped', 'Cancelled', etc.",
#     'Description': 'A string representing the status or stage that each order is in. This can include states like Shipped, Cancelled, On Hold, and more.',
#     'Relationships with other columns': 'Can be used to analyze trends over time by comparing it against shippedDate and requiredDate. It helps in understanding the flow of orders through different stages from placement until completion or cancellation.',
#     'Sample value': 'Shipped'},
#    {'Column': 'comments',
#     'Possible meaning': 'Additional notes about an order, such as special requests or issues encountered during processing.',
#     'Description': 'A string containing any additional comments related to the orders. This can include customer-specific instructions, internal remarks from staff members, etc.',
#     'Relationships with other columns': 'Can provide context for understanding specific statuses or delays in shippedDate compared to orderDate and requiredDate. It helps in identifying issues that may affect delivery times or customer satisfaction.',
#     'Sample value': 'Check on availability.'},
#    {'Column': 'customerNumber',
#     'Possible meaning': 'Unique identifier for each customer who placed an order.',
#     'Description': 'An integer representing a unique identifier assigned to customers. This can be used to link orders back to specific customers and analyze their purchasing behavior over time.',
#     'Relationships with other columns': 'Can be linked with external tables containing customer information, such as name or contact details. It helps in identifying repeat customers and analyzing order patterns per customer.',
#     'Sample value': 363}]},
#  {'Data Dictionary for payments.csv': [{'Column': 'customerNumber',
#     'Possible meaning': 'Unique identifier for each customer.',
#     'Description': 'An integer value that uniquely identifies a specific customer within the dataset.',
#     'Relationships with other columns': 'This column could be used to link payment records back to individual customers, possibly correlating with data in another table or file containing detailed customer information.',
#     'Sample value': 103},
#    {'Column': 'checkNumber',
#     'Possible meaning': 'Unique identifier for each check/payment transaction.',
#     'Description': 'A string that uniquely identifies a payment made by the customer, likely used to track individual transactions or checks.',
#     'Relationships with other columns': "This column could be related to 'paymentDate' and 'amount', as it represents an instance of a specific amount being paid on a certain date.",
#     'Sample value': 'HQ336336'},
#    {'Column': 'paymentDate',
#     'Possible meaning': 'The date when the payment was made or processed.',
#     'Description': "A string representing the date in 'YYYY-MM-DD' format, indicating on which day a particular transaction occurred.",
#     'Relationships with other columns': "This column is likely to be analyzed alongside 'amount', as it provides context for when payments of specific amounts were made. It could also correlate with customer payment patterns over time.",
#     'Sample value': '2004-10-19'},
#    {'Column': 'amount',
#     'Possible meaning': 'The monetary amount paid in a transaction.',
#     'Description': 'A floating point number representing the total sum of money that was transferred or paid for each record.',
#     'Relationships with other columns': "This column is directly related to 'checkNumber' and 'paymentDate', as it specifies how much was paid on what date through which check. It could also be analyzed in conjunction with 'customerNumber' to understand payment behavior per customer.",
#     'Sample value': 6066.78}]},
#  {'Data Dictionary for productlines.csv': [{'Column': 'productLine',
#     'Possible meaning': 'Category or type of products available.',
#     'Description': 'This column lists different categories or lines of products such as Classic Cars, Motorcycles etc., which are offered by the company.',
#     'Relationships with other columns': "It could be related to 'textDescription' and potentially used in conjunction with sales data from another file to analyze product line performance.",
#     'Sample value': 'Classic Cars'},
#    {'Column': 'textDescription',
#     'Possible meaning': 'Detailed textual description of the product line.',
#     'Description': 'This column contains detailed descriptions for each product line, providing information about features and characteristics of products within that category.',
#     'Relationships with other columns': "It is directly related to 'productLine' as it provides a more in-depth explanation of what each product line entails.",
#     'Sample value': 'Attention car enthusiasts: Make your wildest car ownership dreams come true. Whether you are looking for classic muscle cars, dream sports cars or movie-inspired miniatures, you will find great choices in this category...'},
#    {'Column': 'htmlDescription',
#     'Possible meaning': 'HTML formatted description of the product line.',
#     'Description': 'This column is intended to hold HTML-formatted descriptions for each product line. However, all values are null indicating that no data has been populated here yet.',
#     'Relationships with other columns': "It should be related to 'productLine' and potentially replace or complement 'textDescription', but currently holds no usable information.",
#     'Sample value': 'None'},
#    {'Column': 'image',
#     'Possible meaning': 'Image associated with the product line.',
#     'Description': "This column is intended for storing image references (like URLs) related to each product line. Similar to 'htmlDescription', all values are null, indicating no images have been linked or uploaded yet.",
#     'Relationships with other columns': "It should be related to 'productLine' and could complement the textual descriptions in 'textDescription'. However, currently holds no usable information.",
#     'Sample value': 'None'}]},
#  {'Data Dictionary for products.csv': [{'Column': 'productCode',
#     'Possible meaning': 'Unique identifier for each product.',
#     'Description': 'A code assigned to uniquely identify a specific product within the inventory or catalog system.',
#     'Relationships with other columns': 'This column is likely used as a primary key and could be related to sales data, stock levels, etc., in other datasets.',
#     'Sample value': 'S10_1678'},
#    {'Column': 'productName',
#     'Possible meaning': 'The name of the product.',
#     'Description': 'A descriptive name given to a specific product that helps identify it among others. It usually reflects what the item is or its brand and model.',
#     'Relationships with other columns': "It can be associated with 'productLine' for categorization purposes, and 'productCode' as an identifier.",
#     'Sample value': '1969 Harley Davidson Ultimate Chopper'},
#    {'Column': 'productLine',
#     'Possible meaning': 'The category or line of products to which the product belongs.',
#     'Description': 'A classification that groups similar types of products together, such as Motorcycles, Classic Cars, etc., for easier management and analysis.',
#     'Relationships with other columns': "It is related to 'productName' in terms of categorization. It can also be used to analyze sales or inventory trends by product category.",
#     'Sample value': 'Motorcycles'},
#    {'Column': 'productScale',
#     'Possible meaning': 'The scale at which the product is made, typically for models and replicas.',
#     'Description': "Indicates how much smaller a model replica is compared to its real-life counterpart. For example, '1:10' means that every unit of measurement on the model represents 10 units in reality.",
#     'Relationships with other columns': "It can be related to 'productName', especially if it's a scale model or toy product.",
#     'Sample value': '1:10'},
#    {'Column': 'productVendor',
#     'Possible meaning': 'The vendor or manufacturer of the product.',
#     'Description': 'Identifies who produces, manufactures, or supplies the products to the store. This can be a company name or brand.',
#     'Relationships with other columns': "It is related to 'productName' and could also be used for supplier analysis in conjunction with sales data.",
#     'Sample value': 'Min Lin Diecast'},
#    {'Column': 'productDescription',
#     'Possible meaning': "A detailed description of the product's features, specifications, or characteristics.",
#     'Description': 'Provides a comprehensive overview of what the product is and its key attributes. This can be used for marketing purposes or to inform customers about the product details.',
#     'Relationships with other columns': "It complements 'productName' by providing more detailed information on each item.",
#     'Sample value': 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.'},
#    {'Column': 'quantityInStock',
#     'Possible meaning': 'The number of units currently in stock.',
#     'Description': 'Represents the current inventory level for a specific product indicating how many items are available for sale or distribution.',
#     'Relationships with other columns': "It can be analyzed alongside 'buyPrice' and 'MSRP' to determine profitability, as well as sales data to track inventory turnover rates.",
#     'Sample value': 7933},
#    {'Column': 'buyPrice',
#     'Possible meaning': 'The price at which the product was purchased from a vendor or supplier.',
#     'Description': 'Represents the cost incurred by the business for each unit of the product. This is crucial for calculating profit margins and managing costs.',
#     'Relationships with other columns': "It can be compared to 'MSRP' to determine gross margin, and analyzed alongside 'quantityInStock' for inventory valuation purposes.",
#     'Sample value': 48.81},
#    {'Column': 'MSRP',
#     'Possible meaning': "Manufacturer's Suggested Retail Price.",
#     'Description': 'The recommended retail price set by the manufacturer at which retailers are advised to sell their products, although it can vary based on market conditions and retailer policies.',
#     'Relationships with other columns': "It is used in conjunction with 'buyPrice' for profit margin analysis. It also influences pricing strategies alongside 'quantityInStock'.",
#     'Sample value': 95.7}]},
#  TextMessage(source='user', models_usage=None, content='Review the data dictionary generated by the file handling agents.', type='TextMessage')]

# %%
# Initialize data dict ingestion agent
final_agent = AssistantAgent(name="Data_Dictionary_Analytics_Suggester",
                             model_client=data_dict_summarizer_client,
                             system_message=prompt
)

response = await final_agent.on_messages(
        [TextMessage(content=f"{responses_TextMessage}\n\nReview the above data dictionary.\n\n{responses_TextMessage}",source="user")], None
    )
response
# Out:
# Response(chat_message=TextMessage(source='Data_Dictionary_Analytics_Suggester', models_usage=RequestUsage(prompt_tokens=12734, completion_tokens=1782), content="### Use Case 1\n- **Use Case ID:** UC001\n- **Title:** Inventory Optimization Based on Product Categories\n- **Description:** Analyze `quantityInStock` in relation to `productLine` and `buyPrice` to identify overstocked or understocked categories, enabling better inventory management and cost optimization.\n- **Data Sources:**\n    - products.csv\n    - productlines.csv\n- **Columns Utilized:**\n    - products.csv.quantityInStock\n    - products.csv.buyPrice\n    - products.csv.productLine\n    - productlines.csv.productLine\n- **Relationships Leveraged:**\n    - The `productLine` column in `products.csv` is related to the `productLine` column in `productlines.csv`, allowing categorization of inventory levels by product category.\n    \n---\n### Use Case 2\n- **Use Case ID:** UC002\n- **Title:** Sales Performance Analysis by Product Line and Region\n- **Description:** Analyze sales performance using `quantityOrdered`, `priceEach`, and the corresponding `productLine` to identify high-demand categories in different regions, facilitating targeted marketing strategies.\n- **Data Sources:**\n    - orderdetails.csv\n    - products.csv\n    - orders.csv\n    - office.csv\n- **Columns Utilized:**\n    - orderdetails.csv.quantityOrdered\n    - orderdetails.csv.priceEach\n    - orderdetails.csv.productCode\n    - products.csv.productLine\n    - products.csv.productCode\n    - orders.csv.orderNumber\n    - orders.csv.customerNumber\n    - customer.csv.salesRepEmployeeNumber\n    - employee.csv.officeCode\n    - office.csv.city\n- **Relationships Leveraged:**\n    - `productCode` in `orderdetails.csv` is linked to `products.csv`, allowing the categorization of ordered products by product line.\n    - `salesRepEmployeeNumber` in `customer.csv` and `employee.csv.officeCode` link customer orders to sales representatives, which can then be associated with office locations.\n\n---\n### Use Case 3\n- **Use Case ID:** UC003\n- **Title:** Customer Payment Behavior Analysis\n- **Description:** Analyze payment trends using `amount`, `paymentDate`, and the corresponding `customerNumber` to identify high-paying customers, late payers, or those with irregular payment patterns.\n- **Data Sources:**\n    - payments.csv\n    - customer.csv\n- **Columns Utilized:**\n    - payments.csv.customerNumber\n    - payments.csv.amount\n    - payments.csv.paymentDate\n- **Relationships Leveraged:**\n    - `customerNumber` links the payment records back to individual customers, allowing for analysis of each customer's payment history and identifying patterns such as timely or delayed payments.\n\n---\n### Use Case 4\n- **Use Case ID:** UC004\n- **Title:** Employee Performance Analysis by Office Location\n- **Description:** Analyze employee performance (e.g., sales, productivity) using `employeeNumber`, `officeCode`, `salesRepEmployeeNumber` from different datasets to assess the efficiency of employees based on their office locations.\n- **Data Sources:**\n    - employee.csv\n    - customer.csv\n    - orders.csv\n- **Columns Utilized:**\n    - employee.csv.employeeNumber\n    - employee.csv.officeCode\n    - customer.csv.salesRepEmployeeNumber\n    - orders.csv.customerNumber\n- **Relationships Leveraged:**\n    - `salesRepEmployeeNumber` links customers to their assigned sales representatives, while `employeeNumber` and `officeCode` provide information on where these employees are based.\n\n---\n### Use Case 5\n- **Use Case ID:** UC005\n- **Title:** Order Fulfillment Time Analysis\n- **Description:** Analyze the time taken between order placement (`orderDate`) and shipment (`shippedDate`) to determine fulfillment efficiency, providing insights into logistics performance.\n- **Data Sources:**\n    - orders.csv\n- **Columns Utilized:**\n    - orders.csv.orderNumber\n    - orders.csv.orderDate\n    - orders.csv ...

# %%
print(response.chat_message.content)
# Out:
# ### Use Case 1
# - **Use Case ID:** UC001
# - **Title:** Inventory Optimization Based on Product Categories
# - **Description:** Analyze `quantityInStock` in relation to `productLine` and `buyPrice` to identify overstocked or understocked categories, enabling better inventory management and cost optimization.
# - **Data Sources:**
#     - products.csv
#     - productlines.csv
# - **Columns Utilized:**
#     - products.csv.quantityInStock
#     - products.csv.buyPrice
#     - products.csv.productLine
#     - productlines.csv.productLine
# - **Relationships Leveraged:**
#     - The `productLine` column in `products.csv` is related to the `productLine` column in `productlines.csv`, allowing categorization of inventory levels by product category.
#
# ---
# ### Use Case 2
# - **Use Case ID:** UC002
# - **Title:** Sales Performance Analysis by Product Line and Region
# - **Description:** Analyze sales performance using `quantityOrdered`, `priceEach`, and the corresponding `productLine` to identify high-demand categories in different regions, facilitating targeted marketing strategies.
# - **Data Sources:**
#     - orderdetails.csv
#     - products.csv
#     - orders.csv
#     - office.csv
# - **Columns Utilized:**
#     - orderdetails.csv.quantityOrdered
#     - orderdetails.csv.priceEach
#     - orderdetails.csv.productCode
#     - products.csv.productLine
#     - products.csv.productCode
#     - orders.csv.orderNumber
#     - orders.csv.customerNumber
#     - customer.csv.salesRepEmployeeNumber
#     - employee.csv.officeCode
#     - office.csv.city
# - **Relationships Leveraged:**
#     - `productCode` in `orderdetails.csv` is linked to `products.csv`, allowing the categorization of ordered products by product line.
#     - `salesRepEmployeeNumber` in `customer.csv` and `employee.csv.officeCode` link customer orders to sales representatives, which can then be associated with office locations.
#
# ---
# ### Use Case 3
# - **Use Case ID:** UC003
# - **Title:** Customer Payment Behavior Analysis
# - **Description:** Analyze payment trends using `amount`, `paymentDate`, and the corresponding `customerNumber` to identify high-paying customers, late payers, or those with irregular payment patterns.
# - **Data Sources:**
#     - payments.csv
#     - customer.csv
# - **Columns Utilized:**
#     - payments.csv.customerNumber
#     - payments.csv.amount
#     - payments.csv.paymentDate
# - **Relationships Leveraged:**
#     - `customerNumber` links the payment records back to individual customers, allowing for analysis of each customer's payment history and identifying patterns such as timely or delayed payments.
#
# ---
# ### Use Case 4
# - **Use Case ID:** UC004
# - **Title:** Employee Performance Analysis by Office Location
# - **Description:** Analyze employee performance (e.g., sales, productivity) using `employeeNumber`, `officeCode`, `salesRepEmployeeNumber` from different datasets to assess the efficiency of employees based on their office locations.
# - **Data Sources:**
#     - employee.csv
#     - customer.csv
#     - orders.csv
# - **Columns Utilized:**
#     - employee.csv.employeeNumber
#     - employee.csv.officeCode
#     - customer.csv.salesRepEmployeeNumber
#     - orders.csv.customerNumber
# - **Relationships Leveraged:**
#     - `salesRepEmployeeNumber` links customers to their assigned sales representatives, while `employeeNumber` and `officeCode` provide information on where these employees are based.
#
# ---
# ### Use Case 5
# - **Use Case ID:** UC005
# - **Title:** Order Fulfillment Time Analysis
# - **Description:** Analyze the time taken between order placement (`orderDate`) and shipment (`shippedDate`) to determine fulfillment efficiency, providing insights into logistics performance.
# - **Data Sources:**
#     - orders.csv
# - **Columns Utilized:**
#     - orders.csv.orderNumber
#     - orders.csv.orderDate
#     - orders.csv.shippedDate
# - **Relationships Leveraged:**
#     - The `orderDate` and `shippedDate` columns in the same dataset provide a direct comparison of order placement to shipment times, allowing for analysis of fulfillment time.
#
# ---
# ### Use Case 6
# - **Use Case ID:** UC006
# - **Title:** Product Profitability Analysis by Vendor and Category
# - **Description:** Analyze profitability using `buyPrice`, `MSRP`, and `quantityInStock` per product vendor (`productVendor`) and category (`productLine`) to identify cost-effective suppliers and high-profit categories.
# - **Data Sources:**
#     - products.csv
# - **Columns Utilized:**
#     - products.csv.productCode
#     - products.csv.buyPrice
#     - products.csv.MSRP
#     - products.csv.quantityInStock
#     - products.csv.productVendor
#     - products.csv.productLine
# - **Relationships Leveraged:**
#     - The `productCode` links each product to its vendor and category, allowing for analysis of cost versus selling price (`buyPrice` vs. `MSRP`) and current inventory levels.
#
# ---
# ### Use Case 7
# - **Use Case ID:** UC007
# - **Title:** Customer Satisfaction Analysis by Order Status and Delivery Time
# - **Description:** Analyze customer satisfaction using the status (`status`), order date (`orderDate`), required date (`requiredDate`), and shipped date (`shippedDate`) to identify potential delays or issues in delivery.
# - **Data Sources:**
#     - orders.csv
# - **Columns Utilized:**
#     - orders.csv.orderNumber
#     - orders.csv.status
#     - orders.csv.orderDate
#     - orders.csv.requiredDate
#     - orders.csv.shippedDate
# - **Relationships Leveraged:**
#     - The `orderDate`, `requiredDate`, and `shippedDate` columns provide insights into the timeline of order fulfillment, while `status` indicates current order status (e.g., shipped, cancelled).
#
# ---
# ### Use Case 8
# - **Use Case ID:** UC008
# - **Title:** Customer Credit Limit Analysis with Payment History
# - **Description:** Analyze customer credit limits (`creditLimit`) in conjunction with their payment history (`amount`, `paymentDate`) to assess the financial risk and manage credit more effectively.
# - **Data Sources:**
#     - customer.csv
#     - payments.csv
# - **Columns Utilized:**
#     - customer.csv.customerNumber
#     - customer.csv.creditLimit
#     - payments.csv.amount
#     - payments.csv.paymentDate
# - **Relationships Leveraged:**
#     - The `customerNumber` links payment history and credit limit information, allowing for assessment of financial risk and identification of customers who may require closer monitoring.
#
# ---
# ### Use Case 9
# - **Use Case ID:** UC009
# - **Title:** Office Operational Efficiency Analysis by Employee Performance
# - **Description:** Analyze the performance of employees (`employeeNumber`) in different offices (`officeCode`) based on sales metrics and order processing times to identify areas for operational improvement.
# - **Data Sources:**
#     - employee.csv
#     - orders.csv
#     - office.csv
# - **Columns Utilized:**
#     - employee.csv.employeeNumber
#     - employee.csv.officeCode
#     - orders.csv.customerNumber
#     - orders.csv.orderDate
#     - orders.csv.shippedDate
#     - office.csv.city
# - **Relationships Leveraged:**
#     - `employeeNumber` links individual employees to their offices, while sales and order processing times provide insights into operational efficiency.
#
# ---
# ### Use Case 10
# - **Use Case ID:** UC010
# - **Title:** Product Line Sales Trend Analysis by Category
# - **Description:** Analyze the quantity ordered (`quantityOrdered`) per product line (`productLine`) to identify sales trends and popular categories over time, aiding in inventory planning.
# - **Data Sources:**
#     - orderdetails.csv
#     - products.csv
# - **Columns Utilized:**
#     - orderdetails.csv.productCode
#     - orderdetails.csv.quantityOrdered
#     - products.csv.productLine
# - **Relationships Leveraged:**
#     - The `productCode` links each product to its category, allowing for analysis of sales trends by product line.
#
# ---
#
# These use cases leverage the relationships between datasets and columns to provide actionable insights into various aspects of business operations. Each case is designed to address specific business objectives such as inventory management, customer satisfaction, financial risk assessment, and operational efficiency.
